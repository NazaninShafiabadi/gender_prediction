# %%
import pandas as pd
from IPython.display import display, Markdown, HTML
from collections import defaultdict
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from data_processing import get_examples, get_category_proportions

# %% [markdown]
# ## Data

# %%
nlexique = pd.read_csv('../data/nlexique.csv')
nlexique = nlexique[['lexeme', 'sg', 'gen']].rename(columns={'sg': 'phon'}).dropna().reset_index(drop=True)
nlexique
# Out:
#            lexeme     phon gen
# 0          à-côté    akOte   m
# 1          à-coup      aku   m
# 2      à-peu-près   apØpʁɛ   m
# 3           à-pic     apik   m
# 4          à-plat     apla   m
# ...           ...      ...  ..
# 30999   zurichois  zyʁikwa   m
# 31000      zydeco   zidəko   f
# 31001      zygoma   zigOma   m
# 31002      zygote    zigɔt   m
# 31003      zyklon   ziklɔ̃   m
#
# [31004 rows x 3 columns]

# %%
get_category_proportions(nlexique, 'gen')
# Out:
# m: 55.5% (17,192.0)
# f: 39.4% (12,219.0)
# b: 5.1% (1,593.0)
# Total: 100% (31,004)

# %%
echantinom = pd.read_csv('../data/Echantinom-full-20210902.csv')
echantinom = echantinom[~echantinom['lemma'].isin(nlexique[nlexique['gen'] == 'b']['lexeme'])] #[['lemma', 'phon', 'gen']]
echantinom
# Out:
#           lemma gen       phon  freq_lex_books  freq_lex_subtitles  \
# 0     berlingue   m   bɛʁ.lɛ̃g            0.34                0.00
# 1        corton   m    kɔʁ.tɔ̃            0.27                0.03
# 2       dabuche   f     da.byʃ            0.54                0.00
# 3           faf   m        faf            0.88                0.07
# 4          gail   f        gaj            0.61                0.00
# ...         ...  ..        ...             ...                 ...
# 4995       palu   m      pa.ly            0.14                0.80
# 4996       talc   m       talk            1.49                1.40
# 4997  sauvetage   m  sO.və.taʒ            3.72                8.32
# 4998      plaid   m       plɛd            1.15                0.34
# 4999        lob   m        lɔb            0.27                0.04
#
#       freq_frcow last_process_broad last_process_narrow prefix compound  ...  \
# 0             34          nonconcat             apocope      0        0  ...
# 1            398             suffix              suffix      0        0  ...
# 2              3             suffix              suffix      0        0  ...
# 3           3422          nonconcat             apocope      0        0  ...
# 4           2471            simplex      native_simplex      0        0  ...
# ...          ...                ...                 ...    ...      ...  ...
# 4995        1431          nonconcat             apocope      0        0  ...
# 4996        2775            simplex           borrowing      0        0  ...
# 4997       60875             suffix              suffix      0        0  ...
# 4998        2889            simplex           borrowing      0        0  ...
# 4999        2965            simplex           borrowing      0        0  ...
#
#      autonomous_base base_stem_phon sfx_allomorph der_stem_phon edit_distance  \
# 0                NaN            NaN           NaN           NaN           NaN
# 1               True            kuʁ            ɔ̃          kɔʁt             2
# 2               True        UNKNOWN            yʃ           dab       UNKNOWN
# 3                NaN            NaN           NaN           NaN           NaN
# 4                NaN            NaN           NaN           NaN           NaN
# ...              ...            ...           ...           ...           ...
# 4995             NaN            NaN           NaN           NaN           NaN
# 4996             NaN            NaN           NaN           NaN           NaN
# 4997            True            sOv            aʒ         sOvət             2
# 4998             NaN            NaN           NaN           NaN           NaN
# 4999             NaN            NaN           NaN           NaN           NaN
#
#          pattern pattern_tf     pattern_rel_tf       base_der_sim  \
# 0            NaN        NaN                NaN                NaN
# 1     _u_~_ɔ_tɔ̃          1           0.015625  0.222162783145905
# 2        UNKNOWN    UNKNOWN            UNKNOWN            UNKNOWN
# 3            NaN        NaN                NaN                NaN
# 4            NaN        NaN                NaN                NaN
# ...          ...        ...                ...                ...
# 4995         NaN        NaN                NaN                NaN
# 4996         NaN        NaN                NaN                NaN
# 4997     _~_ətaʒ          1  0.011494252873563  0.252674728631973
# 4998         NaN        NaN                NaN                NaN
# 4999         NaN        NaN                NaN                NaN
#
#              offset_sim
# 0                   NaN
# 1     0.158108526129264
# 2               UNKNOWN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4995                NaN
# 4996                NaN
# 4997  0.614848479997584
# 4998                NaN
# 4999                NaN
#
# [4534 rows x 25 columns]

# %%
get_category_proportions(echantinom, 'last_process_broad')
# Out:
# simplex: 42.9% (1,943.0)
# suffix: 37.5% (1,701.0)
# conversion: 10.4% (473.0)
# polylexical: 5.3% (240.0)
# nonconcat: 2.1% (96.0)
# prefix: 1.8% (81.0)
# Total: 100% (4,534)

# %%
phon_test = pd.read_csv('../data/phon_test.csv')
get_category_proportions(phon_test, 'gen')
# Out:
# m: 63.4% (2,873.0)
# f: 36.6% (1,659.0)
# Total: 100% (4,532)

# %%
orth_train = pd.read_csv('../data/orth_train.csv')
get_category_proportions(orth_train, 'gen')
# Out:
# m: 57.6% (14,319.0)
# f: 42.4% (10,561.0)
# Total: 100% (24,880)

# %%
phon_train = pd.read_csv('../data/phon_train.csv')
get_category_proportions(phon_train, 'gen')
# Out:
# m: 57.6% (14,319.0)
# f: 42.4% (10,561.0)
# Total: 100% (24,880)

# %%
# Get proportions of certain suffixes in the dataset
def ends_with_suffix(lemma, suffix):
    return lemma.endswith(suffix)

# Merge flexique (for the trainingset sample) and echantinom (for the suffix tag)
# flexique = nlexique.rename(columns={'lexeme': 'lemma'})
# merged_datasets = pd.merge(echantinom, flexique, on='lemma', how='left')
# suffix_df = merged_datasets[merged_datasets['last_process_broad'] == 'suffix']

suffixes = ['age', 'ère', 'ion', 'eur', 'ule', 'ane', 'che', 'sse', 'oge']
suffix_counts = []

for suffix in suffixes:
    suffix_data = nlexique[nlexique['lexeme'].apply(ends_with_suffix, args=(suffix,))]
    
    total = len(suffix_data)
    masc_data = suffix_data[suffix_data['gen'] == 'm']
    fem_data = suffix_data[suffix_data['gen'] == 'f']
    
    masc_count = len(masc_data)
    fem_count = len(fem_data)
    
    masc_prop = masc_count / total if total > 0 else 0
    fem_prop = fem_count / total if total > 0 else 0
    
    masc_examples = masc_data['lexeme'].sample(min(3, masc_count)).tolist()
    fem_examples = fem_data['lexeme'].sample(min(3, fem_count)).tolist()
    
    suffix_counts.append({
        'Suffix': suffix,
        'Total': total,
        'Masculine': masc_count,
        'Feminine': fem_count,
        'Masc_Proportion': masc_prop,
        'Fem_Proportion': fem_prop,
        'Masc_Examples': masc_examples,
        'Fem_Examples': fem_examples
    })

result_df = pd.DataFrame(suffix_counts)
result_df
# Out:
#   Suffix  Total  Masculine  Feminine  Masc_Proportion  Fem_Proportion  \
# 0    age    895        878        11         0.981006        0.012291
# 1    ère    469         87       378         0.185501        0.805970
# 2    ion   1791         68      1723         0.037968        0.962032
# 3    eur   1552       1458        88         0.939433        0.056701
# 4    ule    155         57        89         0.367742        0.574194
# 5    ane    113         36        59         0.318584        0.522124
# 6    che    255         57       178         0.223529        0.698039
# 7    sse    284         34       240         0.119718        0.845070
# 8    oge      9          5         4         0.555556        0.444444
#
#                                   Masc_Examples  \
# 0             [briquetage, foulage, pèlerinage]
# 1           [cache-brassière, viscère, mystère]
# 2                [billion, fourmi-lion, horion]
# 3         [poinçonneur, processeur, fumigateur]
# 4                  [régule, spicule, préambule]
# 5                      [butane, choane, iguane]
# 6              [caniche, guinche, tournebroche]
# 7  [hauts-de-chausse, entrecuisse, interclasse]
# 8              [arrière-loge, éloge, nécrologe]
#
#                          Fem_Examples
# 0            [demi-page, image, rage]
# 1   [bordelière, vipère, mi-carrière]
# 2  [copulation, automation, légation]
# 3         [saveur, lourdeur, rondeur]
# 4         [bascule, forficule, seule]
# 5            [douane, gitane, pavane]
# 6      [ganache, escarmouche, douche]
# 7         [mairesse, rousse, vinasse]
# 8            [horloge, loge, épitoge]

# %%
orth_preds_x10 = pd.read_csv('../results/echantinom_orth_preds_x10.csv')
orth_preds_x10.rename(columns={"Predicted Gender": "orth_pred", "True Gender": "true", "Form": 'lemma'}, inplace=True)
orth_preds_x10
# Out:
#                      lemma orth_pred true  \
# 0                       an         m    m
# 1                       bi         m    m
# 2                       as         m    m
# 3                       té         m    m
# 4                      pie         f    f
# ...                    ...       ...  ...
# 45305    approvisionnement         m    m
# 45306    sous-alimentation         f    f
# 45307   cul-de-basse-fosse         m    m
# 45308  marie-couche-toi-là         f    f
# 45309  transsubstantiation         f    f
#
#                                      Class Probabilities   Set  Run suffix
# 0      [('n', {'f': 0.4085073173046112, 'm': 0.591492...  test    1      0
# 1      [('i', {'f': 0.16074861586093903, 'm': 0.83925...  test    1      0
# 2      [('s', {'f': 0.2868475317955017, 'm': 0.713152...  test    1      0
# 3      [('é', {'f': 0.3696044683456421, 'm': 0.630395...  test    1      0
# 4      [('e', {'f': 0.11107771843671799, 'm': 0.88892...  test    1      0
# ...                                                  ...   ...  ...    ...
# 45305  [('t', {'f': 0.07809196412563324, 'm': 0.92190...  test   10   ment
# 45306  [('n', {'f': 0.38623788952827454, 'm': 0.61376...  test   10    ion
# 45307  [('e', {'f': 0.23680555820465088, 'm': 0.76319...  test   10      0
# 45308  [('à', {'f': 0.28149473667144775, 'm': 0.71850...  test   10      0
# 45309  [('n', {'f': 0.38623788952827454, 'm': 0.61376...  test   10    ion
#
# [45310 rows x 7 columns]

# %%
phon_preds_x10 = pd.read_csv('../results/echantinom_phon_preds_x10.csv')
phon_preds_x10.rename(columns={"Predicted Gender": "phon_pred", "True Gender": "true", "Form": 'phon'}, inplace=True)
phon_preds_x10
# Out:
#                       phon phon_pred true  \
# 0                        ɛ         m    f
# 1                        u         f    m
# 2                        ɛ         m    m
# 3                        o         m    f
# 4                       ba         m    m
# ...                    ...       ...  ...
# 45365      kɔ̃fidɑ̃sjalite         f    f
# 45366      ɛ̃kɔ̃patibilite         f    f
# 45367      suzalimɑ̃tasjɔ̃         f    f
# 45368      tʁɑ̃splɑ̃tasjɔ̃         f    f
# 45369  tʁɑ̃ssypstɑ̃tjasjɔ̃         f    f
#
#                                      Class Probabilities   Set  Run suffix
# 0      [('ɛ', {'f': 0.14882417023181915, 'm': 0.85117...  test    1      0
# 1      [('u', {'f': 0.3157658278942108, 'm': 0.684234...  test    1      0
# 2      [('ɛ', {'f': 0.14882417023181915, 'm': 0.85117...  test    1      0
# 3      [('o', {'f': 0.5670557618141174, 'm': 0.432944...  test    1      0
# 4      [('a', {'f': 0.39993923902511597, 'm': 0.60006...  test    1      0
# ...                                                  ...   ...  ...    ...
# 45365  [('e', {'f': 0.5326544642448425, 'm': 0.467345...  test   10    ité
# 45366  [('e', {'f': 0.5326544642448425, 'm': 0.467345...  test   10    ité
# 45367  [('̃', {'f': 0.6368642449378967, 'm': 0.363135...  test   10    ion
# 45368  [('̃', {'f': 0.6368642449378967, 'm': 0.363135...  test   10    ion
# 45369  [('̃', {'f': 0.6368642449378967, 'm': 0.363135...  test   10    ion
#
# [45370 rows x 7 columns]

# %% [markdown]
# ## Run analyses

# %%
# Select the run with the most errors for each model

# For orthographic model
orth_errors = orth_preds_x10[orth_preds_x10['orth_pred'] != orth_preds_x10['true']]
orth_error_counts = orth_errors.groupby('Run').size()
orth_max_error_run = orth_error_counts.idxmax()
orth_errors_max = orth_errors[orth_errors['Run'] == orth_max_error_run]

# For phonetic model
phon_errors = phon_preds_x10[phon_preds_x10['phon_pred'] != phon_preds_x10['true']]
phon_error_counts = phon_errors.groupby('Run').size()
phon_max_error_run = phon_error_counts.idxmax()
phon_errors_max = phon_errors[phon_errors['Run'] == phon_max_error_run]

# %%
print("Orthographic predictions")
get_category_proportions(orth_errors, 'true')

print("\nPhonetic predictions")
get_category_proportions(phon_errors, 'true')
# Out:
# Orthographic predictions
# m: 50.1% (2,119.0)
# f: 49.9% (2,111.0)
# Total: 100% (4,230)
#
# Phonetic predictions
# f: 52.5% (4,720.0)
# m: 47.5% (4,276.0)
# Total: 100% (8,996)

# %%
# Merge them based on their correspondance in nlexique
orth_errors_with_phon = orth_errors_max.merge(nlexique[['lexeme', 'phon']], 
                                              left_on='lemma', 
                                              right_on='lexeme', 
                                              how='inner')
orth_errors_with_phon
# Out:
#                 lemma orth_pred true  \
# 0                 mer         m    f
# 1                 nef         m    f
# 2                 bru         m    f
# 3                 obi         m    f
# 4                 mob         m    f
# ..                ...       ...  ...
# 436     chèvrefeuille         f    m
# 437    contre-courant         f    m
# 438   perpendiculaire         m    f
# 439   transatlantique         f    m
# 440  contre-la-montre         f    m
#
#                                    Class Probabilities   Set  Run  \
# 0    [('r', {'f': 0.4957234859466553, 'm': 0.504276...  test    9
# 1    [('f', {'f': 0.3697991371154785, 'm': 0.630200...  test    9
# 2    [('u', {'f': 0.742748498916626, 'm': 0.2572515...  test    9
# 3    [('i', {'f': 0.220277801156044, 'm': 0.7797221...  test    9
# 4    [('b', {'f': 0.12944133579730988, 'm': 0.87055...  test    9
# ..                                                 ...   ...  ...
# 436  [('e', {'f': 0.24833141267299652, 'm': 0.75166...  test    9
# 437  [('t', {'f': 0.25025129318237305, 'm': 0.74974...  test    9
# 438  [('e', {'f': 0.24833141267299652, 'm': 0.75166...  test    9
# 439  [('e', {'f': 0.24833141267299652, 'm': 0.75166...  test    9
# 440  [('e', {'f': 0.24833141267299652, 'm': 0.75166...  test    9
#
#                lexeme           phon
# 0                 mer            mɛʁ
# 1                 nef            nɛf
# 2                 bru            bʁy
# 3                 obi            Obi
# 4                 mob            mɔb
# ..                ...            ...
# 436     chèvrefeuille       ʃɛvʁəfœj
# 437    contre-courant    kɔ̃tʁəkuʁɑ̃
# 438   perpendiculaire  pɛʁpɑ̃dikylɛʁ
# 439   transatlantique  tʁɑ̃zatlɑ̃tik
# 440  contre-la-montre  kɔ̃tʁəlamɔ̃tʁ
#
# [441 rows x 8 columns]

# %%
# Find common errors based on the phonetic transcription and merge df
common_errors = orth_errors_with_phon[orth_errors_with_phon['phon'].isin(phon_errors_max['phon'])]
common_errors
# Out:
#                 lemma orth_pred true  \
# 2                 bru         m    f
# 3                 obi         m    f
# 4                 mob         m    f
# 5                 clé         m    f
# 6                 glu         m    f
# ..                ...       ...  ...
# 434     soutien-gorge         f    m
# 435     archimandrite         f    m
# 438   perpendiculaire         m    f
# 439   transatlantique         f    m
# 440  contre-la-montre         f    m
#
#                                    Class Probabilities   Set  Run  \
# 2    [('u', {'f': 0.742748498916626, 'm': 0.2572515...  test    9
# 3    [('i', {'f': 0.220277801156044, 'm': 0.7797221...  test    9
# 4    [('b', {'f': 0.12944133579730988, 'm': 0.87055...  test    9
# 5    [('é', {'f': 0.42137300968170166, 'm': 0.57862...  test    9
# 6    [('u', {'f': 0.742748498916626, 'm': 0.2572515...  test    9
# ..                                                 ...   ...  ...
# 434  [('e', {'f': 0.24833141267299652, 'm': 0.75166...  test    9
# 435  [('e', {'f': 0.24833141267299652, 'm': 0.75166...  test    9
# 438  [('e', {'f': 0.24833141267299652, 'm': 0.75166...  test    9
# 439  [('e', {'f': 0.24833141267299652, 'm': 0.75166...  test    9
# 440  [('e', {'f': 0.24833141267299652, 'm': 0.75166...  test    9
#
#                lexeme           phon
# 2                 bru            bʁy
# 3                 obi            Obi
# 4                 mob            mɔb
# 5                 clé            kle
# 6                 glu            gly
# ..                ...            ...
# 434     soutien-gorge     sutjɛ̃gɔʁʒ
# 435     archimandrite    aʁʃimɑ̃dʁit
# 438   perpendiculaire  pɛʁpɑ̃dikylɛʁ
# 439   transatlantique  tʁɑ̃zatlɑ̃tik
# 440  contre-la-montre  kɔ̃tʁəlamɔ̃tʁ
#
# [242 rows x 8 columns]

# %%
final_merged_errors = common_errors.merge(phon_errors_max, 
                                          on='phon', 
                                          suffixes=('_orth', '_phon'))

final_errors = final_merged_errors[['lemma', 'phon', 'orth_pred', 'phon_pred', 'true_phon']] \
                                    .rename(columns={'true_phon': 'true'})

final_errors
# Out:
#                 lemma           phon orth_pred phon_pred true
# 0                 bru            bʁy         m         m    f
# 1                 obi            Obi         m         m    f
# 2                 mob            mɔb         m         m    f
# 3                 clé            kle         m         m    f
# 4                 glu            gly         m         m    f
# ..                ...            ...       ...       ...  ...
# 237     soutien-gorge     sutjɛ̃gɔʁʒ         f         f    m
# 238     archimandrite    aʁʃimɑ̃dʁit         f         f    m
# 239   perpendiculaire  pɛʁpɑ̃dikylɛʁ         m         m    f
# 240   transatlantique  tʁɑ̃zatlɑ̃tik         f         f    m
# 241  contre-la-montre  kɔ̃tʁəlamɔ̃tʁ         f         f    m
#
# [242 rows x 5 columns]

# %%
# Checking for error mismatches
same_predictions = final_errors['orth_pred'] == final_errors['phon_pred']
match_count = same_predictions.sum()
mismatch_count = (~same_predictions).sum()
total_count = len(final_errors)

print(f"Total number of errors: {total_count}")
print(f"Number of matching predictions: {match_count}")
print(f"Number of mismatching predictions: {mismatch_count}")
print(f"Percentage of matching predictions: {match_count / total_count * 100:.2f}%")
final_errors[~same_predictions]
# Out:
# Total number of errors: 242
# Number of matching predictions: 241
# Number of mismatching predictions: 1
# Percentage of matching predictions: 99.59%
#    lemma phon orth_pred phon_pred true
# 27  part  paʁ         m         f    m

# %%
# Merge error dataframe with echantinom
merged_errors_echantinom = final_errors.merge(echantinom, on='lemma', how='left')
merged_errors_echantinom = merged_errors_echantinom.drop(["phon_pred", "gen", "phon_y"], axis=1).rename(columns={"orth_pred": "pred", "phon_x": "phon"})
cols_to_remove = [col for col in merged_errors_echantinom.columns if merged_errors_echantinom[col].isna().all()]
merged_errors_echantinom.drop(columns=cols_to_remove, inplace=True)
print(f"Removed columns with only NaN values: {cols_to_remove}")
merged_errors_echantinom
# Out:
# Removed columns with only NaN values: []
#                 lemma           phon pred true  freq_lex_books  \
# 0                 bru            bʁy    m    f            3.24
# 1                 obi            Obi    m    f            0.07
# 2                 mob            mɔb    m    f            0.68
# 3                 clé            kle    m    f           48.58
# 4                 glu            gly    m    f            2.57
# ..                ...            ...  ...  ...             ...
# 237     soutien-gorge     sutjɛ̃gɔʁʒ    f    m            8.65
# 238     archimandrite    aʁʃimɑ̃dʁit    f    m            0.61
# 239   perpendiculaire  pɛʁpɑ̃dikylɛʁ    m    f            0.74
# 240   transatlantique  tʁɑ̃zatlɑ̃tik    f    m            2.50
# 241  contre-la-montre  kɔ̃tʁəlamɔ̃tʁ    f    m            0.00
#
#      freq_lex_subtitles  freq_frcow last_process_broad last_process_narrow  \
# 0                  1.45        3673            simplex      native_simplex
# 1                  0.30        1606            simplex           borrowing
# 2                  0.93       10736          nonconcat             apocope
# 3                118.13      441735            simplex      native_simplex
# 4                  0.56        1648            simplex      native_simplex
# ..                  ...         ...                ...                 ...
# 237                5.86       10755        polylexical     native_compound
# 238                0.00         472            simplex      native_simplex
# 239                0.04           0         conversion        conversion-A
# 240                0.19           1         conversion        conversion-A
# 241                0.80           0        polylexical         agglomerate
#
#     prefix  ... autonomous_base base_stem_phon sfx_allomorph der_stem_phon  \
# 0        0  ...             NaN            NaN           NaN           NaN
# 1        0  ...             NaN            NaN           NaN           NaN
# 2        0  ...             NaN            NaN           NaN           NaN
# 3        0  ...             NaN            NaN           NaN           NaN
# 4        0  ...             NaN            NaN           NaN           NaN
# ..     ...  ...             ...            ...           ...           ...
# 237      0  ...             NaN            NaN           NaN           NaN
# 238      0  ...             NaN            NaN           NaN           NaN
# 239      0  ...             NaN            NaN           NaN           NaN
# 240  trans  ...             NaN            NaN           NaN           NaN
# 241      0  ...             NaN            NaN           NaN           NaN
#
#     edit_distance pattern pattern_tf pattern_rel_tf base_der_sim offset_sim
# 0             NaN     NaN        NaN            NaN          NaN        NaN
# 1             NaN     NaN        NaN            NaN          NaN        NaN
# 2             NaN     NaN        NaN            NaN          NaN        NaN
# 3             NaN     NaN        NaN            NaN          NaN        NaN
# 4             NaN     NaN        NaN            NaN          NaN        NaN
# ..            ...     ...        ...            ...          ...        ...
# 237           NaN     NaN        NaN            NaN          NaN        NaN
# 238           NaN     NaN        NaN            NaN          NaN        NaN
# 239           NaN     NaN        NaN            NaN          NaN        NaN
# 240           NaN     NaN        NaN            NaN          NaN        NaN
# 241           NaN     NaN        NaN            NaN          NaN        NaN
#
# [242 rows x 26 columns]

# %%
gender_errors = merged_errors_echantinom['pred'].value_counts()         # There are more m predicted as f than vice versa
gender_percentages = gender_errors / gender_errors.sum() * 100
gender_distribution = pd.DataFrame({
    'Count': gender_errors,
    'Percentage': gender_percentages
})
gender_distribution
# Out:
#    Count  Percentage
# f    135   55.785124
# m    107   44.214876

# %%
process_counts = merged_errors_echantinom['last_process_broad'].value_counts()
total = process_counts.sum()
process_percentages = process_counts / total * 100
process_distribution = pd.DataFrame({
    'Count': process_counts,
    'Percentage': process_percentages,
    'Examples': process_counts.index.map(lambda x: ', '.join(get_examples('last_process_broad', x, merged_errors_echantinom)))
})
process_distribution
# Out:
#              Count  Percentage  \
# simplex        159   65.702479
# suffix          27   11.157025
# nonconcat       17    7.024793
# conversion      17    7.024793
# polylexical     15    6.198347
# prefix           7    2.892562
#
#                                                       Examples
# simplex                cola, bastringue, vertèbre, nonce, vice
# suffix         cyanure, noirceur, minceur, formulaire, pendule
# nonconcat           carme, pitaine, thalasso, conso, berlingue
# conversion   hongre, conventionnel, maxillaire, plantigrade...
# polylexical  serre-tête, croquemitaine, franc-maçonne, paus...
# prefix       contrepoison, vicomte, mi-juillet, antigène, m...

# %%
merged_errors_echantinom['last_process_narrow'].value_counts() # We have 21 borrowings, which are:
merged_errors_echantinom[merged_errors_echantinom['last_process_narrow'] == 'borrowing']['lemma'].tolist()
# Out:
# ['obi',
#  'kipa',
#  'city',
#  'cola',
#  'miss',
#  'lama',
#  'sauna',
#  'squaw',
#  'drive',
#  'vodka',
#  'razzia',
#  'vahiné',
#  'mantra',
#  'alcade',
#  'pin-up',
#  'maharani',
#  'start-up',
#  'pipe-line',
#  'superstar',
#  'desiderata',
#  'strip-tease']

# %% [markdown]
# ### Diving into the suffixes

# %%
process_counts = merged_errors_echantinom['suffix'].value_counts()
total = process_counts.sum()
process_percentages = process_counts / total * 100
process_distribution = pd.DataFrame({
    'Count': process_counts,
    'Percentage': process_percentages,
    'Examples': process_counts.index.map(lambda x: ', '.join(get_examples('suffix', x, merged_errors_echantinom)))
})
process_distribution
# Out:
#       Count  Percentage                                       Examples
# 0       209   86.363636  nage, vicomte, amaryllis, pause-café, imposte
# eurF     11    4.545455  rondeur, rousseur, ferveur, chaleur, blondeur
# aire      2    0.826446                    perpendiculaire, formulaire
# ôse       2    0.826446                                ventôse, nivôse
# ureM      2    0.826446                               sulfure, cyanure
# ule       2    0.826446                                 ovule, pendule
# aine      2    0.826446                             pitaine, capitaine
# ose       1    0.413223                                        lactose
# ique      1    0.413223                                   barbiturique
# cule      1    0.413223                                     corpuscule
# ite       1    0.413223                                        lignite
# uche      1    0.413223                                        matuche
# iche      1    0.413223                                        caniche
# ia        1    0.413223                                        fuchsia
# eurM      1    0.413223                                         videur
# if        1    0.413223                                         porcif
# aneM      1    0.413223                                         butane
# in        1    0.413223                                          catin
# el        1    0.413223                                  conventionnel

# %%
# Wrongly predicted suffixes in both models
suffix_gender_counts = merged_errors_echantinom.groupby(['suffix', 'true']).size().unstack(fill_value=0)

# Merge suffix_gender_counts into process_distribution
process_distribution['m'] = suffix_gender_counts['m']
process_distribution['f'] = suffix_gender_counts['f']
process_distribution = process_distribution.sort_values('Count', ascending=False)
process_distribution = process_distribution[process_distribution.index != '0']
process_distribution
# Out:
#       Count  Percentage                                       Examples  m   f
# eurF     11    4.545455  rondeur, rousseur, ferveur, chaleur, blondeur  0  11
# aire      2    0.826446                    perpendiculaire, formulaire  1   1
# ôse       2    0.826446                                ventôse, nivôse  2   0
# ureM      2    0.826446                               sulfure, cyanure  2   0
# ule       2    0.826446                                 ovule, pendule  2   0
# aine      2    0.826446                             pitaine, capitaine  2   0
# ia        1    0.413223                                        fuchsia  1   0
# in        1    0.413223                                          catin  0   1
# aneM      1    0.413223                                         butane  1   0
# if        1    0.413223                                         porcif  0   1
# eurM      1    0.413223                                         videur  1   0
# cule      1    0.413223                                     corpuscule  0   1
# iche      1    0.413223                                        caniche  1   0
# uche      1    0.413223                                        matuche  1   0
# ite       1    0.413223                                        lignite  1   0
# ique      1    0.413223                                   barbiturique  1   0
# ose       1    0.413223                                        lactose  1   0
# el        1    0.413223                                  conventionnel  1   0

# %%
plt.figure(figsize=(18, len(process_distribution) * 0.4))
ax = process_distribution[['m', 'f']].plot(kind='barh', stacked=True, color=['skyblue', 'orange'], edgecolor='black')

plt.title('Distribution of Wrongly Predicted Suffixes by Gender', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Suffix', fontsize=12)
plt.legend(title='Gender', bbox_to_anchor=(1.05, 1), loc='upper left')

# Remove top and right spines
sns.despine()

# Add value labels and examples on each segment of the bars
for suffix in process_distribution.index:
    total_width = process_distribution.loc[suffix, 'm'] + process_distribution.loc[suffix, 'f']
    examples = process_distribution.loc[suffix, 'Examples'].split(', ')[:3]
    examples_text = ', '.join(examples)
    ax.text(total_width + 0.2, ax.get_yticks()[list(process_distribution.index).index(suffix)], 
            f'{int(total_width)} ({examples_text})', va='center', ha='left')

plt.show()

# %% [markdown]
# ### Diving into the simplicia

# %%
# Look for most common endings (although not suffixes)
simplex_data  = merged_errors_echantinom[merged_errors_echantinom['last_process_broad'] == "simplex"][["lemma", "true"]]
lemma_gender = dict(zip(simplex_data['lemma'], simplex_data['true']))
endings = defaultdict(lambda: defaultdict(list))
for lemma, gender in lemma_gender.items():
    endings[lemma[-1]][gender].append(lemma)        # Group by last letter
    if len(lemma) > 1:
        endings[lemma[-2:]][gender].append(lemma)   # Group by last two letters 
    if len(lemma) > 2:
        endings[lemma[-3:]][gender].append(lemma)   # Group by last three letters

print("Most common endings:")
# Note: we print here the true genders
for ending, genders in sorted(endings.items(), key=lambda x: sum(len(v) for v in x[1].values()), reverse=True)[:20]:
    total = sum(len(words) for words in genders.values())
    print(f"\n-{ending}: {total} words")
    for gender, words in genders.items():
        percentage = len(words) / total * 100
        print(f"  {gender}: {len(words)} words ({percentage:.1f}%)")
        words_to_print = words[:20]
        print(f"    {', '.join(words_to_print)}", end="")
        if len(words) > 20:
            print(f" ... and {len(words) - 20} more")
        else:
            print()
# Out:
# Most common endings:
#
# -e: 114 words
#   f: 40 words (35.1%)
#     cage, toge, rage, puce, acre, gaze, nage, robe, hâte, loge, icône, trame, hydre, spire, bugle, brume, bible, piste, chape, spore ... and 20 more
#   m: 74 words (64.9%)
#     rêve, mime, vice, dine, vote, jute, pagne, fifre, ongle, renne, cadre, torse, blase, morse, baile, azote, crane, cotre, nonce, culte ... and 54 more
#
# -re: 27 words
#   f: 6 words (22.2%)
#     acre, hydre, spire, spore, fenêtre, vertèbre
#   m: 21 words (77.8%)
#     fifre, cadre, cotre, frère, lierre, congre, poivre, cigare, pampre, marbre, boutre, mercure, salaire, gruyère, murmure, camphre, matamore, grimoire, genièvre, cimeterre ... and 1 more
#
# -te: 14 words
#   f: 6 words (42.9%)
#     hâte, piste, crypte, riposte, imposte, langouste
#   m: 8 words (57.1%)
#     vote, jute, azote, culte, diabète, tumulte, quarante, archimandrite
#
# -a: 12 words
#   f: 3 words (25.0%)
#     kipa, vodka, razzia
#   m: 9 words (75.0%)
#     cola, lama, sauna, delta, mantra, dahlia, placenta, desiderata, manzanilla
#
# -ne: 12 words
#   m: 10 words (83.3%)
#     dine, pagne, renne, crane, vergne, arcane, chevesne, pipe-line, bourgogne, macfarlane
#   f: 2 words (16.7%)
#     icône, chicane
#
# -le: 10 words
#   m: 5 words (50.0%)
#     ongle, baile, bidule, drille, squale
#   f: 5 words (50.0%)
#     bugle, bible, capsule, chasuble, mandibule
#
# -n: 8 words
#   f: 2 words (25.0%)
#     façon, guenon
#   m: 6 words (75.0%)
#     scion, tison, bastion, troufion, histrion, centurion
#
# -on: 8 words
#   f: 2 words (25.0%)
#     façon, guenon
#   m: 6 words (75.0%)
#     scion, tison, bastion, troufion, histrion, centurion
#
# -se: 8 words
#   m: 8 words (100.0%)
#     torse, blase, morse, causse, gymnase, bidasse, carrosse, strip-tease
#
# -ce: 7 words
#   f: 2 words (28.6%)
#     puce, justice
#   m: 5 words (71.4%)
#     vice, nonce, calice, silence, pancrace
#
# -ge: 6 words
#   f: 5 words (83.3%)
#     cage, toge, rage, nage, loge
#   m: 1 words (16.7%)
#     litige
#
# -r: 6 words
#   f: 6 words (100.0%)
#     cour, fleur, rumeur, tumeur, couleur, superstar
#
# -ve: 6 words
#   m: 5 words (83.3%)
#     rêve, drive, zouave, margrave, conclave
#   f: 1 words (16.7%)
#     alcôve
#
# -me: 6 words
#   m: 2 words (33.3%)
#     mime, grime
#   f: 4 words (66.7%)
#     trame, brume, septime, enclume
#
# -ue: 6 words
#   f: 3 words (50.0%)
#     cloque, applique, ammoniaque
#   m: 3 words (50.0%)
#     flingue, fourgue, bastringue
#
# -u: 5 words
#   f: 5 words (100.0%)
#     bru, glu, eau, vertu, tribu
#
# -ur: 5 words
#   f: 5 words (100.0%)
#     cour, fleur, rumeur, tumeur, couleur
#
# -ion: 5 words
#   m: 5 words (100.0%)
#     scion, bastion, troufion, histrion, centurion
#
# -s: 4 words
#   f: 4 words (100.0%)
#     miss, bastos, brebis, amaryllis
#
# -ane: 4 words
#   m: 3 words (75.0%)
#     crane, arcane, macfarlane
#   f: 1 words (25.0%)
#     chicane

# %%
def get_most_complex_endings(endings):
    complex_endings = defaultdict(lambda: defaultdict(list))
    word_to_ending = {}

    # Sort all possible endings by length (longest first)
    all_endings = sorted(endings.keys(), key=len, reverse=True)

    for ending in all_endings:
        for gender, words in endings[ending].items():
            for word in words:
                if word not in word_to_ending:
                    complex_endings[ending][gender].append(word)
                    word_to_ending[word] = ending

    return complex_endings

complex_endings = get_most_complex_endings(endings)

print("Most common endings:")
for ending, genders in sorted(complex_endings.items(), key=lambda x: sum(len(v) for v in x[1].values()), reverse=True)[:20]:
    total = sum(len(words) for words in genders.values())
    print(f"\n-{ending}: {total} words")
    for gender, words in genders.items():
        percentage = len(words) / total * 100
        print(f"  {gender}: {len(words)} words ({percentage:.1f}%)")
        words_to_print = words[:20]
        print(f"    {', '.join(words_to_print)}", end="")
        if len(words) > 20:
            print(f" ... and {len(words) - 20} more")
        else:
            print()
# Out:
# Most common endings:
#
# -ion: 5 words
#   m: 5 words (100.0%)
#     scion, bastion, troufion, histrion, centurion
#
# -ane: 4 words
#   m: 3 words (75.0%)
#     crane, arcane, macfarlane
#   f: 1 words (25.0%)
#     chicane
#
# -eur: 4 words
#   f: 4 words (100.0%)
#     fleur, rumeur, tumeur, couleur
#
# -ste: 4 words
#   f: 4 words (100.0%)
#     piste, riposte, imposte, langouste
#
# -age: 3 words
#   f: 3 words (100.0%)
#     cage, rage, nage
#
# -ime: 3 words
#   m: 2 words (66.7%)
#     mime, grime
#   f: 1 words (33.3%)
#     septime
#
# -ice: 3 words
#   m: 2 words (66.7%)
#     vice, calice
#   f: 1 words (33.3%)
#     justice
#
# -gne: 3 words
#   m: 3 words (100.0%)
#     pagne, vergne, bourgogne
#
# -ase: 3 words
#   m: 3 words (100.0%)
#     blase, gymnase, strip-tease
#
# -ire: 3 words
#   f: 1 words (33.3%)
#     spire
#   m: 2 words (66.7%)
#     salaire, grimoire
#
# -tre: 3 words
#   m: 2 words (66.7%)
#     cotre, boutre
#   f: 1 words (33.3%)
#     fenêtre
#
# -ère: 3 words
#   m: 3 words (100.0%)
#     frère, gruyère, cimetière
#
# -ave: 3 words
#   m: 3 words (100.0%)
#     zouave, margrave, conclave
#
# -ule: 3 words
#   m: 1 words (33.3%)
#     bidule
#   f: 2 words (66.7%)
#     capsule, mandibule
#
# -che: 3 words
#   m: 3 words (100.0%)
#     prêche, guinche, panache
#
# -sse: 3 words
#   m: 3 words (100.0%)
#     causse, bidasse, carrosse
#
# -que: 3 words
#   f: 3 words (100.0%)
#     cloque, applique, ammoniaque
#
# -gue: 3 words
#   m: 3 words (100.0%)
#     flingue, fourgue, bastringue
#
# -oge: 2 words
#   f: 2 words (100.0%)
#     toge, loge
#
# -ine: 2 words
#   m: 2 words (100.0%)
#     dine, pipe-line

# %%
# Calculate entropy to measure how uncertain the ending's prediction is
def calculate_entropy(gender_counts):
    total = sum(gender_counts.values())
    probabilities = [count/total for count in gender_counts.values()]
    return -sum(p * np.log2(p) for p in probabilities if p > 0)

ending_data = []
for ending, genders in endings.items():
    total = sum(len(words) for words in genders.values())
    if total >= 5:  # Only consider endings with at least 5 words
        gender_counts = {gender: len(words) for gender, words in genders.items()}
        entropy = calculate_entropy(gender_counts)
        ending_data.append((ending, gender_counts, entropy, total))

# Sort endings by entropy (most problematic first) and total count
# problematic = endings that don't clearly indicate one gender or the other
ending_data.sort(key=lambda x: (x[2], x[3]), reverse=True)        
ending_data
# Out:
# [('le', {'m': 5, 'f': 5}, 1.0, 10),
#  ('ue', {'f': 3, 'm': 3}, 1.0, 6),
#  ('te', {'f': 6, 'm': 8}, 0.9852281360342515, 14),
#  ('e', {'f': 40, 'm': 74}, 0.9348490242345944, 114),
#  ('me', {'m': 2, 'f': 4}, 0.9182958340544896, 6),
#  ('ce', {'f': 2, 'm': 5}, 0.863120568566631, 7),
#  ('a', {'f': 3, 'm': 9}, 0.8112781244591328, 12),
#  ('n', {'f': 2, 'm': 6}, 0.8112781244591328, 8),
#  ('on', {'f': 2, 'm': 6}, 0.8112781244591328, 8),
#  ('re', {'f': 6, 'm': 21}, 0.7642045065086203, 27),
#  ('ne', {'m': 10, 'f': 2}, 0.6500224216483541, 12),
#  ('ge', {'f': 5, 'm': 1}, 0.6500224216483541, 6),
#  ('ve', {'m': 5, 'f': 1}, 0.6500224216483541, 6),
#  ('se', {'m': 8}, -0.0, 8),
#  ('r', {'f': 6}, -0.0, 6),
#  ('u', {'f': 5}, -0.0, 5),
#  ('ur', {'f': 5}, -0.0, 5),
#  ('ion', {'m': 5}, -0.0, 5)]

# %%
# Plot
top_endings = ending_data[:20]
endings = [data[0] for data in top_endings]
m_counts = [data[1].get('m', 0) for data in top_endings]
f_counts = [data[1].get('f', 0) for data in top_endings]

# Calculate percentages
totals = [m + f for m, f in zip(m_counts, f_counts)]
m_percentages = [m/total*100 for m, total in zip(m_counts, totals)]
f_percentages = [f/total*100 for f, total in zip(f_counts, totals)]

# Create the stacked bar plot
fig, ax = plt.subplots(figsize=(15, 10))
ax.bar(endings, m_percentages, label='Masculine')
ax.bar(endings, f_percentages, bottom=m_percentages, label='Feminine')
ax.set_title('Gender distribution for most problematic endings\n', fontsize=16)
ax.set_xlabel('Ending', fontsize=12)
ax.set_ylabel('Percentage', fontsize=12)
ax.legend(title='Gender')

# Add percentage labels
for i, (m, f) in enumerate(zip(m_percentages, f_percentages)):
    ax.text(i, m/2, f'{m:.1f}%', ha='center', va='center')
    ax.text(i, m + f/2, f'{f:.1f}%', ha='center', va='center')

# Add total count on top of each bar
for i, total in enumerate(totals):
    ax.text(i, 100, f'n={total}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Analyze gender distribution by word length
length_gender = defaultdict(lambda: defaultdict(int))
for lemma, gender in lemma_gender.items():
    length_gender[len(lemma)][gender] += 1

print("\nWord length and gender distribution:")
for length in sorted(length_gender.keys()):
    total = sum(length_gender[length].values())
    print(f"\n{length} letters: {total} words")
    for gender, count in length_gender[length].items():
        percentage = count / total * 100
        print(f"  {gender}: {count} words ({percentage:.1f}%)")
# Out:
# Word length and gender distribution:
#
# 3 letters: 5 words
#   f: 5 words (100.0%)
#
# 4 letters: 24 words
#   f: 15 words (62.5%)
#   m: 9 words (37.5%)
#
# 5 letters: 38 words
#   m: 22 words (57.9%)
#   f: 16 words (42.1%)
#
# 6 letters: 33 words
#   f: 13 words (39.4%)
#   m: 20 words (60.6%)
#
# 7 letters: 25 words
#   m: 16 words (64.0%)
#   f: 9 words (36.0%)
#
# 8 letters: 18 words
#   m: 12 words (66.7%)
#   f: 6 words (33.3%)
#
# 9 letters: 9 words
#   m: 5 words (55.6%)
#   f: 4 words (44.4%)
#
# 10 letters: 5 words
#   m: 4 words (80.0%)
#   f: 1 words (20.0%)
#
# 11 letters: 1 words
#   m: 1 words (100.0%)
#
# 13 letters: 1 words
#   m: 1 words (100.0%)

# %%
# Plot
lengths = sorted(length_gender.keys())
genders = list(set(gender for length_dict in length_gender.values() for gender in length_dict.keys()))
data = {gender: [length_gender[length].get(gender, 0) for length in lengths] for gender in genders}

# Create the stacked bar plot
fig, ax = plt.subplots(figsize=(14, 7))  
bottom = np.zeros(len(lengths))
for gender in genders:
    ax.bar(range(len(lengths)), data[gender], bottom=bottom, label=gender)
    bottom += data[gender]

ax.set_title('Word Length and Gender Distribution', fontsize=16)
ax.set_xlabel('Word Length', fontsize=12)
ax.set_ylabel('Number of Words', fontsize=12)
ax.legend(title='Gender')

# Set x-ticks and labels
ax.set_xticks(range(len(lengths)))
ax.set_xticklabels(lengths)

# Add value labels on the bars
for i, length in enumerate(lengths):
    total = sum(data[gender][i] for gender in genders)
    ax.text(i, total, str(total), ha='center', va='bottom')

# Add percentage labels
for i, length in enumerate(lengths):
    total = sum(data[gender][i] for gender in genders)
    bottom = 0
    for gender in genders:
        count = data[gender][i]
        if count > 0:
            percentage = count / total * 100
            ax.text(i, bottom + count/2, f'{percentage:.1f}%', 
                    ha='center', va='center')
        bottom += count

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Orth/phon agreement vs. disagreement

# %%
orth_incorrect = orth_preds_x10[orth_preds_x10.orth_pred != orth_preds_x10.true]
orth_incorrect
# Out:
#                  lemma orth_pred true  \
# 42                 foi         m    f
# 43                 ire         m    f
# 44                 nef         m    f
# 48                 ive         m    f
# 58                 glu         m    f
# ...                ...       ...  ...
# 45202    franc-maçonne         m    f
# 45241   monte-en-l'air         f    m
# 45269   contre-attaque         m    f
# 45288  transatlantique         f    m
# 45290  perpendiculaire         m    f
#
#                                      Class Probabilities   Set  Run
# 42     [('i', {'f': 0.16074861586093903, 'm': 0.83925...  test    1
# 43     [('e', {'f': 0.11107771843671799, 'm': 0.88892...  test    1
# 44     [('f', {'f': 0.43117114901542664, 'm': 0.56882...  test    1
# 48     [('e', {'f': 0.11107771843671799, 'm': 0.88892...  test    1
# 58     [('u', {'f': 0.37645187973976135, 'm': 0.62354...  test    1
# ...                                                  ...   ...  ...
# 45202  [('e', {'f': 0.23680555820465088, 'm': 0.76319...  test   10
# 45241  [('r', {'f': 0.29656296968460083, 'm': 0.70343...  test   10
# 45269  [('e', {'f': 0.23680555820465088, 'm': 0.76319...  test   10
# 45288  [('e', {'f': 0.23680555820465088, 'm': 0.76319...  test   10
# 45290  [('e', {'f': 0.23680555820465088, 'm': 0.76319...  test   10
#
# [4230 rows x 6 columns]

# %%
orth_preds= pd.read_csv('../results/echantinom_orth_preds_new.csv')
phon_preds= pd.read_csv('../results/echantinom_phon_preds_new.csv')

phon_preds
# Out:
#                   Form             Alt Form Predicted Gender True Gender  \
# 0                    o                  eau                m           f
# 1                    ɛ                  ais                m           m
# 2                    ɛ                 haie                m           m
# 3                    1                   an                m           m
# 4                    4                  hun                m           m
# ...                ...                  ...              ...         ...
# 4526     tɛʁʒivɛʁsasj2       tergiversation                f           f
# 4527     suzalim1tasj2    sous-alimentation                f           f
# 4528    ʁəstʁyktyʁasj2      restructuration                f           f
# 4529    tʁadisjOnalizm      traditionalisme                m           m
# 4530  tʁ1ssypst1tjasj2  transsubstantiation                f           f
#
#                                     Class Probabilities   Set suffix
# 0     [('o', {'m': 0.6905112266540527, 'f': 0.309488...  test      0
# 1     [('ɛ', {'m': 0.6576897501945496, 'f': 0.342310...  test      0
# 2     [('ɛ', {'m': 0.6576897501945496, 'f': 0.342310...  test      0
# 3     [('1', {'m': 0.6691492199897766, 'f': 0.330850...  test      0
# 4     [('4', {'m': 0.580463171005249, 'f': 0.4195368...  test      0
# ...                                                 ...   ...    ...
# 4526  [('2', {'m': 0.7829316258430481, 'f': 0.217068...  test    ion
# 4527  [('2', {'m': 0.7829316258430481, 'f': 0.217068...  test    ion
# 4528  [('2', {'m': 0.7829316258430481, 'f': 0.217068...  test    ion
# 4529  [('m', {'m': 0.2641342580318451, 'f': 0.735865...  test   isme
# 4530  [('2', {'m': 0.7829316258430481, 'f': 0.217068...  test    ion
#
# [4531 rows x 7 columns]

# %%
phon_preds[(phon_preds['True Gender'] == 'm') & (phon_preds['Predicted Gender'] == 'f')].shape[0]
# Out:
# 323

# %%
common_lemmas = set(orth_preds['Form']) & set(phon_preds['Alt Form'])

# Create dictionaries for quick lookup
orth_dict = dict(zip(orth_preds['Form'], orth_preds['Predicted Gender']))
phon_dict = dict(zip(phon_preds['Alt Form'], phon_preds['Predicted Gender']))
true_gender_dict = dict(zip(orth_preds['Form'], orth_preds['True Gender']))
phon_transcription_dict = dict(zip(orth_preds['Form'], orth_preds['Alt Form']))

# Count agreements
agreements = sum(orth_dict[lemma] == phon_dict[lemma] for lemma in common_lemmas)

# Calculate percentage
agreement_percentage = (agreements / len(common_lemmas)) * 100

print(f"Total lemmas: {len(common_lemmas)}")
print(f"Lemmas with agreed predictions: {agreements}")
print(f"Agreement percentage: {agreement_percentage:.2f}%")
# Out:
# Total lemmas: 4531
# Lemmas with agreed predictions: 3812
# Agreement percentage: 84.13%

# %%
disagreements = [
    (lemma, phon_transcription_dict[lemma], true_gender_dict[lemma], orth_dict[lemma], phon_dict[lemma])
    for lemma in common_lemmas
    if orth_dict[lemma] != phon_dict[lemma]
]

disagreement_df = pd.DataFrame(disagreements, columns=['Lemma', 'Phonemic Transcription', 'True Gender', 'Orth Prediction', 'Phon Prediction'])
print("\nSample of disagreements:")
print(disagreement_df.head(20))

# Save disagreements to CSV
# disagreement_df.to_csv('model_disagreements.csv', index=False)
# Out:
# Sample of disagreements:
#          Lemma Phonemic Transcription True Gender Orth Prediction  \
# 0         girl                   gœʁl           f               m
# 1     panthère                  p1tɛʁ           f               f
# 2        fusée                   fyze           f               f
# 3       morale                  mOʁal           f               f
# 4     parabole                paʁabɔl           f               f
# 5    macintosh               makintɔʃ           m               m
# 6       misère                  mizɛʁ           f               f
# 7       évadée                  Evade           f               f
# 8        recul                  ʁəkyl           m               m
# 9    berlingue                 bɛʁl3g           m               f
# 10         jet                   dʒɛt           m               m
# 11      flemme                   flɛm           f               f
# 12   monticule                m2tikyl           m               f
# 13  saint-père                  s3pɛʁ           m               f
# 14       dîner                   dine           m               m
# 15         bis                    bis           m               m
# 16       prout                   pʁut           m               m
# 17     aquavit                akwavit           m               m
# 18    parcelle                 paʁsɛl           f               f
# 19        imam                   imam           m               m
#
#    Phon Prediction
# 0                f
# 1                m
# 2                m
# 3                m
# 4                m
# 5                f
# 6                m
# 7                m
# 8                f
# 9                m
# 10               f
# 11               m
# 12               m
# 13               m
# 14               f
# 15               f
# 16               f
# 17               f
# 18               m
# 19               f

# %%
# Calculate percentages for disagreements
orth_correct_disagreements = (disagreement_df['Orth Prediction'] == disagreement_df['True Gender']).sum()
phon_correct_disagreements = (disagreement_df['Phon Prediction'] == disagreement_df['True Gender']).sum()

orth_correct_percentage = (orth_correct_disagreements / len(disagreement_df)) * 100
phon_correct_percentage = (phon_correct_disagreements / len(disagreement_df)) * 100

print(f"Total disagreements: {len(disagreement_df)}")
print(f"Orthographic model correct in disagreements: {orth_correct_percentage:.2f}%")
print(f"Phonemic model correct in disagreements: {phon_correct_percentage:.2f}%")
# Out:
# Total disagreements: 719
# Orthographic model correct in disagreements: 76.63%
# Phonemic model correct in disagreements: 23.37%

# %%
def color_cells(val, true_gender):
    color = 'background-color: '
    if val == true_gender:
        return color + 'lightgreen'
    else:
        return color + 'lightcoral'

styled_df = disagreement_df.style.apply(lambda row: [
    '',  # Lemma
    '',  # Phonemic Transcription
    '',  # True Gender
    color_cells(row['Orth Prediction'], row['True Gender']),
    color_cells(row['Phon Prediction'], row['True Gender'])
], axis=1)

display(HTML(styled_df.to_html()))
# Out:
# <style type="text/css">
# #T_405d8_row0_col3, #T_405d8_row1_col4, #T_405d8_row2_col4, #T_405d8_row3_col4, #T_405d8_row4_col4, #T_405d8_row5_col4, #T_405d8_row6_col4, #T_405d8_row7_col4, #T_405d8_row8_col4, #T_405d8_row9_col3, #T_405d8_row10_col4, #T_405d8_row11_col4, #T_405d8_row12_col3, #T_405d8_row13_col3, #T_405d8_row14_col4, #T_405d8_row15_col4, #T_405d8_row16_col4, #T_405d8_row17_col4, #T_405d8_row18_col4, #T_405d8_row19_col4, #T_405d8_row20_col4, #T_405d8_row21_col4, #T_405d8_row22_col4, #T_405d8_row23_col4, #T_405d8_row24_col4, #T_405d8_row25_col4, #T_405d8_row26_col4, #T_405d8_row27_col4, #T_405d8_row28_col4, #T_405d8_row29_col3, #T_405d8_row30_col4, #T_405d8_row31_col4, #T_405d8_row32_col4, #T_405d8_row33_col4, #T_405d8_row34_col4, #T_405d8_row35_col3, #T_405d8_row36_col4, #T_405d8_row37_col4, #T_405d8_row38_col4, #T_405d8_row39_col3, #T_405d8_row40_col4, #T_405d8_row41_col3, #T_405d8_row42_col3, #T_405d8_row43_col3, #T_405d8_row44_col3, #T_405d8_row45_col4, #T_405d8_row46_col3, #T_405d8_row47_col4, #T_405d8_row48_col3, #T_405d8_row49_col4, #T_405d8_row50_col3, #T_405d8_row51_col4, #T_405d8_row52_col4, #T_405d8_row53_col3, #T_405d8_row54_col4, #T_405d8_row55_col3, #T_405d8_row56_col4, #T_405d8_row57_col4, #T_405d8_row58_col4, #T_405d8_row59_col4, #T_405d8_row60_col4, #T_405d8_row61_col4, #T_405d8_row62_col4, #T_405d8_row63_col4, #T_405d8_row64_col3, #T_405d8_row65_col3, #T_405d8_row66_col4, #T_405d8_row67_col3, #T_405d8_row68_col4, #T_405d8_row69_col4, #T_405d8_row70_col4, #T_405d8_row71_col4, #T_405d8_row72_col3, #T_405d8_row73_col3, #T_405d8_row74_col4, #T_405d8_row75_col4, #T_405d8_row76_col4, #T_405d8_row77_col4, #T_405d8_row78_col4, #T_405d8_row79_col4, #T_405d8_row80_col4, #T_405d8_row81_col4, #T_405d8_row82_col4, #T_405d8_row83_col4, #T_405d8_row84_col4, #T_405d8_row85_col4, #T_405d8_row86_col4, #T_405d8_row87_col4, #T_405d8_row88_col4, #T_405d8_row89_col4, #T_405d8_row90_col4, #T_405d8_row91_col4, #T_405d8_row92_col4, #T_405d8_row93_col3, #T_405d8_row94_col4, #T_405d8_row95_col3, #T_405d8_row96_col4, #T_405d8_row97_col4, #T_405d8_row98_col4, #T_405d8_row99_col3, #T_405d8_row100_col4, #T_405d8_row101_col4, #T_405d8_row102_col4, #T_405d8_row103_col3, #T_405d8_row104_col3, #T_405d8_row105_col4, #T_405d8_row106_col4, #T_405d8_row107_col4, #T_405d8_row108_col3, #T_405d8_row109_col4, #T_405d8_row110_col3, #T_405d8_row111_col4, #T_405d8_row112_col4, #T_405d8_row113_col4, #T_405d8_row114_col4, #T_405d8_row115_col4, #T_405d8_row116_col4, #T_405d8_row117_col4, #T_405d8_row118_col4, #T_405d8_row119_col3, #T_405d8_row120_col3, #T_405d8_row121_col4, #T_405d8_row122_col4, #T_405d8_row123_col4, #T_405d8_row124_col4, #T_405d8_row125_col3, #T_405d8_row126_col4, #T_405d8_row127_col4, #T_405d8_row128_col4, #T_405d8_row129_col4, #T_405d8_row130_col3, #T_405d8_row131_col4, #T_405d8_row132_col3, #T_405d8_row133_col4, #T_405d8_row134_col4, #T_405d8_row135_col4, #T_405d8_row136_col4, #T_405d8_row137_col4, #T_405d8_row138_col4, #T_405d8_row139_col3, #T_405d8_row140_col3, #T_405d8_row141_col4, #T_405d8_row142_col4, #T_405d8_row143_col4, #T_405d8_row144_col4, #T_405d8_row145_col4, #T_405d8_row146_col3, #T_405d8_row147_col4, #T_405d8_row148_col3, #T_405d8_row149_col4, #T_405d8_row150_col4, #T_405d8_row151_col4, #T_405d8_row152_col4, #T_405d8_row153_col3, #T_405d8_row154_col4, #T_405d8_row155_col4, #T_405d8_row156_col3, #T_405d8_row157_col4, #T_405d8_row158_col4, #T_405d8_row159_col4, #T_405d8_row160_col3, #T_405d8_row161_col4, #T_405d8_row162_col4, #T_405d8_row163_col4, #T_405d8_row164_col3, #T_405d8_row165_col4, #T_405d8_row166_col4, #T_405d8_row167_col4, #T_405d8_row168_col4, #T_405d8_row169_col3, #T_405d8_row170_col3, #T_405d8_row171_col4, #T_405d8_row172_col4, #T_405d8_row173_col4, #T_405d8_row174_col4, #T_405d8_row175_col4, #T_405d8_row176_col4, #T_405d8_row177_col4, #T_405d8_row178_col4, #T_405d8_row179_col3, #T_405d8_row180_col3, #T_405d8_row181_col4, #T_405d8_row182_col3, #T_405d8_row183_col4, #T_405d8_row184_col3, #T_405d8_row185_col4, #T_405d8_row186_co ...

# %%
orth_correct = orth_preds[orth_preds['Predicted Gender'] == orth_preds['True Gender']]
orth_correct['phon_pred'] = phon_preds['Predicted Gender'] 
pd.crosstab(orth_correct['Predicted Gender'], orth_correct.phon_pred)
# Out:
# /var/folders/9z/vb7mydrn6kj_y7zf3cgd_26h0000gn/T/ipykernel_3432/2878635265.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orth_correct['phon_pred'] = phon_preds['Predicted Gender']
# phon_pred           f     m
# Predicted Gender
# f                 465   973
# m                 894  1770

# %%
orth_correct = orth_preds_x10[orth_preds_x10.orth_pred == orth_preds_x10.true]
orth_correct['phon_pred'] = phon_preds_x10.phon_pred 
pd.crosstab(orth_correct.orth_pred, orth_correct.phon_pred)
# Out:
# C:\Users\ninan\AppData\Local\Temp\ipykernel_1388\2831827995.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orth_correct['phon_pred'] = phon_preds_x10.phon_pred
# phon_pred     f      m
# orth_pred
# f          5328   9151
# m          9395  17216

# %% [markdown]
# ### Phon/orth agreement vs. disagreement

# %%
phon_incorrect = phon_preds_x10[phon_preds_x10.phon_pred != phon_preds_x10['true']]
phon_incorrect
# Out:
#                 phon phon_pred true  \
# 0                  ɛ         m    f
# 1                  u         f    m
# 3                  o         m    f
# 5                 ʁu         m    f
# 7                 œj         f    m
# ...              ...       ...  ...
# 45277  tʁɑ̃zatlɑ̃tik         f    m
# 45284  kɔ̃tʁəlamɔ̃tʁ         f    m
# 45286  pɛʁpɑ̃dikylɛʁ         m    f
# 45297  mOdysOpEʁɑ̃di         f    m
# 45298  ɛ̃tɛʁnasjOnal         f    m
#
#                                      Class Probabilities   Set  Run
# 0      [('ɛ', {'f': 0.14882417023181915, 'm': 0.85117...  test    1
# 1      [('u', {'f': 0.3157658278942108, 'm': 0.684234...  test    1
# 3      [('o', {'f': 0.5670557618141174, 'm': 0.432944...  test    1
# 5      [('u', {'f': 0.3157658278942108, 'm': 0.684234...  test    1
# 7      [('j', {'f': 0.06026039645075798, 'm': 0.93973...  test    1
# ...                                                  ...   ...  ...
# 45277  [('k', {'f': 0.41414210200309753, 'm': 0.58585...  test   10
# 45284  [('ʁ', {'f': 0.28374531865119934, 'm': 0.71625...  test   10
# 45286  [('ʁ', {'f': 0.28374531865119934, 'm': 0.71625...  test   10
# 45297  [('i', {'f': 0.3824596405029297, 'm': 0.617540...  test   10
# 45298  [('l', {'f': 0.21200042963027954, 'm': 0.78799...  test   10
#
# [8996 rows x 6 columns]

# %%
phon_correct = phon_preds[phon_preds['Predicted Gender'] == phon_preds['True Gender']]
phon_correct['orth_pred'] = orth_preds['Predicted Gender'] 
pd.crosstab(phon_correct['Predicted Gender'], phon_correct.orth_pred)
# Out:
# /var/folders/9z/vb7mydrn6kj_y7zf3cgd_26h0000gn/T/ipykernel_3432/4067333434.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phon_correct['orth_pred'] = orth_preds['Predicted Gender']
# orth_pred           f     m
# Predicted Gender
# f                 437   730
# m                 953  1596

# %%
phon_correct = phon_preds_x10[phon_preds_x10.phon_pred == phon_preds_x10.true]
phon_correct['orth_pred'] = orth_preds_x10.orth_pred 
pd.crosstab(phon_correct.phon_pred, phon_correct.orth_pred)
# Out:
# C:\Users\ninan\AppData\Local\Temp\ipykernel_1388\2820111615.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phon_correct['orth_pred'] = orth_preds_x10.orth_pred
# orth_pred     f      m
# phon_pred
# f          4487   7383
# m          9014  15440

# %% [markdown]
# ### Orth/phon agreement vs. disagreement

# %%
orth_incorrect = orth_preds_x10[orth_preds_x10.orth_pred != orth_preds_x10['true']]
orth_incorrect
# Out:
#                  lemma orth_pred true  \
# 42                 foi         m    f
# 43                 ire         m    f
# 44                 nef         m    f
# 48                 ive         m    f
# 58                 glu         m    f
# ...                ...       ...  ...
# 45202    franc-maçonne         m    f
# 45241   monte-en-l'air         f    m
# 45269   contre-attaque         m    f
# 45288  transatlantique         f    m
# 45290  perpendiculaire         m    f
#
#                                      Class Probabilities   Set  Run
# 42     [('i', {'f': 0.16074861586093903, 'm': 0.83925...  test    1
# 43     [('e', {'f': 0.11107771843671799, 'm': 0.88892...  test    1
# 44     [('f', {'f': 0.43117114901542664, 'm': 0.56882...  test    1
# 48     [('e', {'f': 0.11107771843671799, 'm': 0.88892...  test    1
# 58     [('u', {'f': 0.37645187973976135, 'm': 0.62354...  test    1
# ...                                                  ...   ...  ...
# 45202  [('e', {'f': 0.23680555820465088, 'm': 0.76319...  test   10
# 45241  [('r', {'f': 0.29656296968460083, 'm': 0.70343...  test   10
# 45269  [('e', {'f': 0.23680555820465088, 'm': 0.76319...  test   10
# 45288  [('e', {'f': 0.23680555820465088, 'm': 0.76319...  test   10
# 45290  [('e', {'f': 0.23680555820465088, 'm': 0.76319...  test   10
#
# [4230 rows x 6 columns]

# %%
orth_correct = orth_preds_x10[orth_preds_x10.orth_pred == orth_preds_x10.true]
orth_correct['phon_pred'] = phon_preds_x10.phon_pred 
pd.crosstab(orth_correct.orth_pred, orth_correct.phon_pred)
# Out:
# C:\Users\ninan\AppData\Local\Temp\ipykernel_1388\2930785969.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orth_correct['phon_pred'] = phon_preds_x10.phon_pred
# phon_pred     f      m
# orth_pred
# f          5328   9151
# m          9395  17216
